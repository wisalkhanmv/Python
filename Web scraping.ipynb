# %% [markdown]
# # Web scraping using BeautifulSoup (alongwith requests + etree)

# %%
#import libraries
import time
import pandas as pd
# from webdriver_manager.chrome import ChromeDriverManager
#import libraries
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %%
# uncomment to install
# !pip install bs4
# !pip install selenium
# !pip install webdriver-manager

# %%
import requests
example = requests.get("http://www.fsf.org/")
html = example.text
html
from bs4 import BeautifulSoup
soup = BeautifulSoup(html)
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="FSF, Free Software Foundation, Free Software, Libre Software" http-equiv="Keywords"/>
#   <meta content="The FSF is a charity with a worldwide mission to advance software freedom." http-equiv="Description"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <base href="https://www.fsf.org/"/>
#   <!--[if lt IE 7]></base><![endif]-->
#   <meta content="width=device-width; initial-scale=0.6666; maximum-scale=1.0; minimum-scale=0.6666" name="viewport"/>
#   <meta content="Plone - https://plone.org" name="generator"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Plone - https://plone.org" name="generator"/>
#   <title>
#    Front Page — Free Software Foundation — working together for free software
#   </title>
# ...

# %%
from lxml import etree

soup = BeautifulSoup(example.content, "html.parser")
e = etree.HTML(str(soup))
e
for i in e.xpath('//ul[@class="initiatives-list"]/li/a/div/p'):
    print(i.text)

# %% [markdown]
# # Scraping Something From WikiPedia

# %%
import requests
from bs4 import BeautifulSoup
from lxml import etree

txt = requests.get('https://en.wikipedia.org/wiki/Dream') #gives a weird value

text = txt.text
text = BeautifulSoup(text)
text.prettify #this gives html

fin_text = BeautifulSoup(txt.content, "html.parser")
fin_text = etree.HTML(str(fin_text))
fin_text #gives weird value

for i in fin_text.xpath('//*[@id="mw-content-text"]/div[1]/p[8]'):
    print(i.text)
# Out:
# From the 1940s to 1985,

# %% [markdown]
# # Web scraping using selenium

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %%
options = Options()
# options.add_argument("--headless")
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)

driver.get('https://maps.google.com')

search_term = 'NUST Islamabad'
driver.find_element_by_xpath('//*[@id="searchboxinput"]').send_keys(search_term + Keys.RETURN)
time.sleep(7)
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - There is no [win32] chromedriver for browser 95.0.4638 in cache
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Trying to download new driver from https://chromedriver.storage.googleapis.com/95.0.4638.69/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Latitude\.wdm\drivers\chromedriver\win32\95.0.4638.69]
# <ipython-input-7-8bb751dbdf8f>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
# <ipython-input-7-8bb751dbdf8f>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="searchboxinput"]').send_keys(search_term + Keys.RETURN)

# %%
data = driver.find_elements_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[7]/div')

name = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[1]/h1/span[1]').text
rating = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[2]/div/div[1]/div[2]/span/span/span').text
reviews = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[2]/div/div[1]/span[1]/span/span/span[2]/span[1]/button').text
category = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[2]/div/div[2]/span[1]/span[1]/button').text

location = ""
plus_code = ""
website = ""
phone_no = ""
health_safety = ""
located_in = ""

try:
    timings = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[7]/div[3]/div[2]').get_attribute("aria-label")
    if timings == None:                     
        timings = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[7]/div[2]/div[2]').get_attribute("aria-label")
except NoSuchElementException:
    try:
        timings = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[7]/div[2]/div[2]').get_attribute("aria-label")
    except:
        timings = 'Unavailable'


for val in data:
    text = val.text
    if text == data[0].text:
        location = text
        continue
    if text[4] == '+':
        plus_code = text
    elif text[0] == '+':
        phone_no = text
    elif text[:6] == 'Health':
        health_safety = text[17:]
    elif text[:7] == 'Located':
        located_in = text[12:]
    else:
        continue

print(f'Name: {name}\nRating: {rating}\nReviews: {reviews}\nCategoty: {category}\nLocation: {location}\nLocated In: {located_in}\nPhone no: {phone_no}\nTimings: {timings}\nHealth safety: {health_safety}\nPlus code: {plus_code}\n URL: {driver.current_url}')
# Out:
# <ipython-input-8-8fe20ea5ae5d>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   data = driver.find_elements_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[7]/div')
# <ipython-input-8-8fe20ea5ae5d>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[1]/h1/span[1]').text
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-8-8fe20ea5ae5d> in <module>
#       1 data = driver.find_elements_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[7]/div')
#       2
# ----> 3 name = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[1]/h1/span[1]').text
# ...

# %%
driver.close()

# %% [markdown]
# # Scraping Daraz.pk

# %%
ratings = [3, 4]
pricing = [(300,500), (1000,1500)]

query = input('Enter search term: ').replace(' ', '%20')
print(f'Modified search term: {query}')
# Out:
# Enter search term: microphones
# Modified search term: microphones

# %%
options = Options()
# options.add_argument("--headless")
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)

names = []
mall = []
prce = []
star = []
revw = []
#for i in pricing:
for j in ratings:
    driver.get(f'https://www.daraz.pk/catalog/?from=input&q={query}&rating={j}')

    for product in driver.find_elements_by_class_name('c2prKC'):
        name = product.find_element_by_class_name('c16H9d').text
        
        try:
            price = int(product.find_element_by_class_name('c3gUW0').text[3:].replace(',',''))
        except ValueError:
            price = 0

        prce.append(price)
        names.append(name)
driver.close()
            
for i in range(len(names)):
    print(f'Name:, {names[i]}, Price:, {prce[i]}')
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Driver [C:\Users\Latitude\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# <ipython-input-6-2c63a564b2c6>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
# <ipython-input-6-2c63a564b2c6>:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for product in driver.find_elements_by_class_name('c2prKC'):
# Name:, 1 Year Official Warranty - Boya M1 Lavalier Collar Microphone for DSLR & Android Phone BY-M1 Mic, Price:, 1668
# Name:, ENRG 3.5mm Microphone Professional Lavalier Omnidirectional Mic 360° Easy Clip for Android and iPhone Mobile Phones (5 Meter), Price:, 499
# ...

# %%
df = pd.DataFrame({'Name':names, 'Price':prce})
df
# Out:
#                                                  Name  Price
# 0   1 Year Official Warranty - Boya M1 Lavalier Co...   1668
# 1   ENRG 3.5mm Microphone Professional Lavalier Om...    499
# 2   3.5 mm Clip Tie Collar Mic for Mobile Phone Sp...    165
# 3   3.5 mm Clip Collar Mic for Voice Recording, Mo...    215
# 4   WS-858 Portable Karaoke Bluetooth Wireless Mic...    765
# ..                                                ...    ...
# 75                  Clip-on Lapel Lavalier Collar Mic    199
# 76  ENRG Condenser Microphone Omnidirectional Mic ...   1725
# 77  Clip Tie Collar Mic for Mobile Phone Speaking ...    161
# 78  PROFESSIONAL LAVALIER MIC - Professional ferro...    280
# 79  ENRG Condenser Microphone Kit Adjustable Mic S...   4999
#
# [80 rows x 2 columns]

# %%
df['Price'].min()
# Out:
# 300

# %%
df['Price'].max()
# Out:
# 1500

# %% [markdown]
# # Scraping twitter

# %%
url = 'https://twitter.com/search?q=%23PakvsNz&src=trend_click&vertical=trends'

options = Options()
#options.add_argument("--headless")
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)

driver.get(url)

# %%
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div[6]/div/div/article/div/div/div/div[2]/div[2]/div[2]/div[1]/div/span[1]').text
time.sleep(7)
# //*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div[3]/div/div/article/div/div/div
# //*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div[3]/div/div/article/div/div/div/div[2]
# //*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div[3]/div/div/article/div/div/div/div[2]/div[2]/div[2]
# //*[@id="id__0b4h0r08yf5n"]
# /html/body/div/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div[10]/div/div/article/div/div/div/div[2]/div[2]/div[2]/div[1]/div
# Out:
# <ipython-input-18-b72f8767ae72>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('/html/body/div/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div[6]/div/div/article/div/div/div/div[2]/div[2]/div[2]/div[1]/div/span[1]').text
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-18-b72f8767ae72> in <module>
# ----> 1 driver.find_element_by_xpath('/html/body/div/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div[6]/div/div/article/div/div/div/div[2]/div[2]/div[2]/div[1]/div/span[1]').text
#       2 time.sleep(7)
#       3 # //*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div[3]/div/div/article/div/div/div
# ...

# %%
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/main/div/div/div/div/div/div[1]/div[1]/div/div/div/div/div[2]/div[2]/div/div/div/form/div[1]/div/div/label/div[2]/div/input').send_keys('Imran khan' + Keys.RETURN)
time.sleep(5)
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div[3]/div/div/div/div[2]/div[1]/div[1]/a/div/div[1]/div[1]/span/span').click()
